# %%
# Dòng 1: 2 khoảng trắng + 1 dấu sao
print("  * ")
# Dòng 2: 1 khoảng trắng + 3 dấu sao
print(" *** ")
# Dòng 3: 0 khoảng trắng + 5 dấu sao
print("*****")
# Out:
#   *
#  ***
# *****

# %%
a1, b1, c1, a2, b2, a3 = map(float, input().split())

diem_tb = (a1 + b1 + c1 + (a2 + b2) * 2 + a3 * 3) / 10

print(f"{diem_tb:.1f}")

# %%
n = int(input("nhap nam sinh:"))
hien_tai= 2026
tuoi= hien_tai-n
if tuoi>=18:
    print("ban da du 18 tuoi")
else:
    print("ban chua du 18 tuoi")

# %%
print('''### # #   ### ###
 #   #  #  #  #
 #   #   # #  #
 #   #  #  #  #
 #   # #   #  #''')

# %%
months = ("January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December")
for month in months:
    print(month)

# %%
for i in range (10):
     print("Hello, world")

# %%
n = int(input("nhap vao mot nam:"))
if (n%400==0) or (n%4==0) and (n%10!=0):
    print(n, "nam nhuan")
else:
    print(n, "khong phai nam nhuan")

# %%
h, m = map(int, input(). split())
gio = h*3600
phut = m*60
tong_giay = h*3600 + m*60
print(tong_giay)

# %%
a, b = map(int, input(). split())
a_mu_b = a**b 
print(a_mu_b)

# %%
x = float(input("gia chiec dong ho(USD): "))
chi_phi_van_chuyen = 10 
thue_nhap_canh = x * 0.3
thue_vat = x * 0.1
tong_tien = x + chi_phi_van_chuyen + thue_nhap_canh +thue_vat
print(f"{tong_tien: .2f}")

# %%
ki_tu_thuong = input()
ma_unicode = ord(ki_tu_thuong)
print(ma_unicode)
ki_tu_hoa = ki_tu_thuong .upper()
print(ki_tu_hoa)

# %%
Danh_sach_ten = input(). split()
ten1 = Danh_sach_ten [0]
ten2 = Danh_sach_ten [1]
ten3 = Danh_sach_ten [2]
print(f"Hi {ten3}, {ten2} and {ten1}.")
