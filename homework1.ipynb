# %% [markdown]
# ### Bai 1: Nhap vao một số nguyên, in ra màn hình giá trị gấp đôi của nó

# %%
a = float(input())
a = a*2
print(a)

# %% [markdown]
# ### Problem 2
# #### Write a function that computes (a - b) * c.

# %%
a = float(input())
b = float(input())
c = float(input())
d = (a - b) * c
print(d)
# Out:
# -3.0

# %% [markdown]
# ### Problem 3
# #### Write a function that returns a + b + a * b.

# %%
a = float(input())
b = float(input())
c = a+b+a*b
print(c)
# Out:
# 3.0

# %% [markdown]
# ### Problem 4
# #### Write a function that returns the count of positive integers k such that 1 <= k < n and k > (n - 1) / 2. (Example: n=9 -> 4).

# %% [markdown]
# ### Problem 6
# #### Write a function that computes the area of a triangle with side lengths a, b, c (use Heron's formula). Raise ValueError if the sides cannot form a triangle.

# %%
a = 3
b = 4
c = 5
p = (a+b+c)/2
cong_thuc_heron = (p*(p-a)*(p-b)*(p-c))**0.5
print(cong_thuc_heron)
# Out:
# 6.0

# %% [markdown]
# ### Problem 7
# #### Write a function that returns True if a, b, c can be the side lengths of a triangle; otherwise return False.

# %%
a = 3
b = 4
c = 5
if a+b >= c and a+c >= b and b+c >= a:
    print("3 canh tren tao thanh 1 tam giac")
else:
    print("3 canh tren khong tao thanh 1 tam giac")
# Out:
# 3 canh tren tao thanh 1 tam giac

# %% [markdown]
# ### Problem 8
# #### Write a function that returns the character that is n positions after character x in the alphabet.
# #### Preserve case and wrap around within A..Z or a..z.

# %%
x = input()
n = int(input())
vt = ord(x) + n 
if ord("A") <= vt <= ord("Z"):
    print(chr(vt))
elif ord("a") <= vt <= ord("Z"):
    print(chr(vt))
else:
    print("khong phai la ki tu chu cai")
# Out:
# khong phai la ki tu chu cai

# %% [markdown]
# ### Problem 9
# #### Write a function that converts an uppercase letter to lowercase. If the input is not a single character, raise ValueError.

# %%
def chuyen_ki_tu(huydzai):
    return huydzai.lower()

print(chuyen_ki_tu('HUYDZAI'))
# Out:
# huydzai

# %% [markdown]
# ### Problem 10
# #### Write a function that, given a lowercase letter, returns a string containing that letter repeated 10 times.

# %%
c = input()
for i in range (10):
    print(c, end )

# %% [markdown]
# ### Problem 12
# #### Write a function that returns a right isosceles triangle of height n using '*'.
# #### Line i (1-indexed) has i '*', joined with newlines.
# #### Example with n = 4
# #### *
# #### **
# #### ***
# #### ****

# %%
n = int(input())
print(n*2)

# %%
a = float(input("nhap chieu rong:"))
b = float(input("nhap chieu dai:"))
if a > b:
    print("loi")
else: 
    dien_tich_hinh_tron= (a/2)**2 * 3.14
    dien_tich_hinh_cn= a*b
    x= dien_tich_hinh_cn - dien_tich_hinh_tron
    ket_qua= round(x,2)
    print(ket_qua)

# %%
c = input("nhap_mot_ki_tu:")
if "A" <= "c" <= "Z":
    print(c.lower())
elif "a" <= "c" <= "z":
    print(c.upper())
else:
    print(c)

# %%
c = input("nhap_mot_ki_tu:")
if ('a'<= 'c' <= 'z') or ('A' <= 'c' <= 'Z'):
    print(c, "la mot ki tu alphabet")
else:
    print(c, "ko phai mot ki tu alphabet")

# %%
a = float(input("nhap canh a:"))
b = float(input("nhap canh b:"))
c = float(input("nhap canh c:"))
if (a+b>c) and (a+c>b) and (b+c>a):
    p= (a+b+c)/2
    s= (p*(p-a)*(p-b)*(p-c))**0.5
    print(f"dien tich tam giac: {s: .1f}")
else: 
    print(" khong phai la 3 canh cua tam giac ")

# %%
s = input("nhap mot chuoi gom cac ki tu thuong do dai >= 20 ")
if len(s) >= 20:
    print("chu cai thu 5 la:" ,s[4])
    print("chu cai thu 9 la:" ,s[8])
else:
    print("chuoi qua ngan")
